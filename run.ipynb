# %%
from rag_pipeline.run import run
from textwrap import fill

x = run(
    "Print text about healthcare?"
)

print(fill(x, width=80))
# Out:
# **The Importance of Healthcare**  Healthcare is a vital aspect of our lives,
# providing essential services to maintain and improve our physical and mental
# well-being. It encompasses a wide range of services, including preventive care,
# diagnosis, treatment, and management of various health conditions.  **Types of
# Healthcare Services**  1.  **Primary Care**: This is the first point of contact
# between a patient and the healthcare system. Primary care providers, such as
# family physicians or general practitioners, offer routine check-ups,
# vaccinations, and health advice. 2.  **Specialized Care**: This type of care is
# provided by specialists who have received advanced training in a specific area
# of medicine. Examples include cardiologists, oncologists, and neurologists. 3.
# **Emergency Care**: This type of care is provided in emergency situations, such
# as accidents or sudden illnesses. Emergency medical services (EMS) and emergency
# ...
